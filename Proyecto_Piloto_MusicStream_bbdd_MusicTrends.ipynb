# %% [markdown]
# # PROYECTO MUSIC STREAM
#
# ANÁLISIS DE POPULARIDAD DE CANCIONES EN LA ERA DIGITAL
#
# El objetivo es identificar las canciones y álbumes más populares en MusicStream, utilizando técnicas de extracción de datos desde diferentes fuentes, como la API de Spotify, y last.fm. Posteriormente, almacenaremos la información en una base de datos y realizaremos consultas para obtener insights clave.

# %% [markdown]
# LIBRERÍAS Y AUTENTIFICACIONES

# %%
# importamos las librerías que necesitaremos:

# Uso de API's
# -----------------------------------------------------------------------
import requests

# Importar librería para interactuar con la API de Spotify y generar los credenciales necesarios para la autentificación 
# -----------------------------------------------------------------------
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# Importar librería para trabajar con variables de entorno en Python, permite cargar variables de entorno desde un archivo .env en el directorio del proyecto
# -----------------------------------------------------------------------
import os
from dotenv import load_dotenv

# Importar librería para trabajar con archivos JSON
# -----------------------------------------------------------------------
import json

# Importar librerías para manipulación y análisis de datos
# -----------------------------------------------------------------------
import pandas as pd
# Importar librerías para procesamiento de texto
# -----------------------------------------------------------------------
import re


# Importar librería para la conexión con MySQL
# -----------------------------------------------------------------------
import mysql.connector
from mysql.connector import errorcode

# Configuración
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None) # para poder visualizar todas las columnas de los DataFrames

# %%
load_dotenv()
# Out:
# Python-dotenv could not parse statement starting at line 1
# Python-dotenv could not parse statement starting at line 8
# Python-dotenv could not parse statement starting at line 11
# True

# %%
sp_clave = os.getenv("Spotify_id")
sp_contraseña = os.getenv("Spotify_secret")

# %%
#Autentificación SPOTIFY:
auth_manager = sp = SpotifyClientCredentials(client_id=sp_clave,
                                             client_secret=sp_contraseña)

sp = spotipy.Spotify(auth_manager=auth_manager)

# %%
#Autentificación LASTFM:
lastfm_clave = os.getenv("lastfm_id")

# %% [markdown]
# FUNCIÓN SACAR CANCIONES DE SPOTIFY

# %%
def canciones_spotify(sp, géneros):
    canciones = {"nombre_artista": [], "nombre_canción": [], "año_lanzamiento": [], "género_musical": [], "tipo": []}
    for anio in range(2019,2024):
        for offset in range(0, 250, 50):
            for genero in géneros:
                datos_trance = sp.search(q=f"genre:{genero} year:{anio}", type="track", limit=50, offset=offset)
                for cancion in datos_trance["tracks"]["items"]:
                    canciones["nombre_artista"].append(cancion["album"]["artists"][0]["name"])
                    canciones["nombre_canción"].append(cancion["name"])
                    canciones["género_musical"].append(f"{genero}")
                    canciones["año_lanzamiento"].append(cancion["album"]["release_date"][0:4])
                    canciones["tipo"].append(cancion["type"])
    df_canciones_spotify = pd.DataFrame(canciones)
    return df_canciones_spotify

# %%
géneros = ['pop','rock','techno','trance']
df_canciones_spotify = canciones_spotify(sp, géneros)

# %%
# guardamos la información de las 5000 canciones de artistas de Spotify en un archivo .csv
df_canciones_spotify.to_csv("spotifydatabase.csv")

# %%
df_datos_spotify=pd.read_csv("spotifydatabase.csv",index_col=0)
# ponemos el index_col= 0 para q no nos cree el Unnamed

# %%
df_datos_spotify
# visualizamos que es correcta la información de Spotify (el índice va a salir pero lo quitamos al hacer el itertuples)
# Out:
#        nombre_artista             nombre_canción  año_lanzamiento  \
# 0     Various Artists               Walk Me Home             2019
# 1     Various Artists                       Wow.             2019
# 2     Various Artists                 Déjame Ser             2019
# 3     Various Artists     I Was Made for Dancin'             2019
# 4     Various Artists                     Malibu             2019
# ...               ...                        ...              ...
# 4995  Various Artists     Rainbow - Original Mix             2023
# 4996  Various Artists           Edge Of Tomorrow             2023
# 4997  Various Artists                  Surrender             2023
# 4998  Various Artists  Memento - Manu Riga Remix             2023
# 4999  Various Artists                       BOTH             2023
#
#      género_musical   tipo
# 0               pop  track
# 1               pop  track
# 2               pop  track
# 3               pop  track
# 4               pop  track
# ...             ...    ...
# 4995         trance  track
# 4996         trance  track
# 4997         trance  track
# 4998         trance  track
# 4999         trance  track
#
# [5000 rows x 5 columns]

# %%
list(df_datos_spotify.itertuples(index=False, name=None))
# aqui no incluye ni el índice ni los títulos de las colmnas

values_spotify = list(df_datos_spotify.itertuples(index=False, name=None))

# %% [markdown]
# FUNCIÓN SACAR CANCIONES DE LASTFM

# %%
# leemos el archivo .csv previamente guardado con la información de Spotify
pd.read_csv("spotifydatabase.csv", index_col=0)
# Out:
#        nombre_artista             nombre_canción  año_lanzamiento  \
# 0     Various Artists               Walk Me Home             2019
# 1     Various Artists                       Wow.             2019
# 2     Various Artists                 Déjame Ser             2019
# 3     Various Artists     I Was Made for Dancin'             2019
# 4     Various Artists                     Malibu             2019
# ...               ...                        ...              ...
# 4995  Various Artists     Rainbow - Original Mix             2023
# 4996  Various Artists           Edge Of Tomorrow             2023
# 4997  Various Artists                  Surrender             2023
# 4998  Various Artists  Memento - Manu Riga Remix             2023
# 4999  Various Artists                       BOTH             2023
#
#      género_musical   tipo
# 0               pop  track
# 1               pop  track
# 2               pop  track
# 3               pop  track
# 4               pop  track
# ...             ...    ...
# 4995         trance  track
# 4996         trance  track
# 4997         trance  track
# 4998         trance  track
# 4999         trance  track
#
# [5000 rows x 5 columns]

# %%
leer_spotify_database = pd.read_csv("spotifydatabase.csv")
spotify_database = leer_spotify_database["nombre_artista"].tolist()

# %%
def obtener_info_artistas_lastfm(spotify_database, lastfm_clave):

    infoartistas = {"nombre_artista": [], "bio": [], "listeners": [], "playcount": [], "similar": []}

    for nombreartista in spotify_database:

        if nombreartista == "Various Artists":  # eliminamos Various Artists para evitar datos erróneos
            continue

        if nombreartista in infoartistas["nombre_artista"]:
            continue  # artista ya procesado, lo saltamos

        else: 
            url = f"http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&artist={nombreartista}&api_key={lastfm_clave}&format=json"

            respuesta = requests.get(url)

            if respuesta.status_code != 200:
                print(f"❌ Error {respuesta.status_code} para {nombreartista}: {respuesta.reason}")
                continue

            try:
                data = respuesta.json()
                similares = []
                for artistaejemplo in data["artist"]["similar"]["artist"]:
                    similares.append(artistaejemplo['name'])

                infoartistas["similar"].append(similares)
                infoartistas["nombre_artista"].append(nombreartista)
                infoartistas["bio"].append(data["artist"]["bio"]["summary"])
                infoartistas["listeners"].append(data["artist"]["stats"]["listeners"])
                infoartistas["playcount"].append(data["artist"]["stats"]["playcount"])

            except (KeyError, ValueError) as e:
                print(f"⚠️ Datos incompletos o error para {nombreartista}: {e}")
                continue

    return infoartistas

# %%
infoartistas_lastfm = obtener_info_artistas_lastfm(spotify_database, lastfm_clave)
print(infoartistas_lastfm)

# Aunque le hayamos solicitado a LastFM información sobre 5000 canciones de distintos artistas, LastFM no siempre tiene información sobre esos artistas,
# por lo que algunos artistas no van a tener su información sobre listeners, bio o artistas similares (Datos incompletos o error)
# Out:
# ⚠️ Datos incompletos o error para Kuber Geetpariha: 'artist'
# ⚠️ Datos incompletos o error para Pankaj,Monika,Pawan: 'artist'
# ⚠️ Datos incompletos o error para Dj Rupendra Style: 'artist'
# ⚠️ Datos incompletos o error para Harendar,Monika,Azad Ansari: 'artist'
# ⚠️ Datos incompletos o error para Azad Ansari,Manju Devi: 'artist'
# ⚠️ Datos incompletos o error para Azad Ansari,Manju Devi: 'artist'
# ⚠️ Datos incompletos o error para KC & The Sunshine Band: 'artist'
# ⚠️ Datos incompletos o error para Pawan, Pankaj,Monika: 'artist'
# ⚠️ Datos incompletos o error para Pankaj,Monika,Pawan: 'artist'
# ⚠️ Datos incompletos o error para Manoj Sahri,Monika: 'artist'
# ⚠️ Datos incompletos o error para Pankaj,Pawan: 'artist'
# ⚠️ Datos incompletos o error para Bharti Studio: 'artist'
# ⚠️ Datos incompletos o error para Mr. Man & the Big Eyes: 'artist'
# ⚠️ Datos incompletos o error para RNG Bros: 'artist'
# ⚠️ Datos incompletos o error para Sargam Audio: 'artist'
# ⚠️ Datos incompletos o error para D N Mishra: 'artist'
# ⚠️ Datos incompletos o error para KC & The Sunshine Band: 'artist'
# ⚠️ Datos incompletos o error para João Neto & Frederico: 'artist'
# ⚠️ Datos incompletos o error para Diego & Victor Hugo: 'artist'
# ⚠️ Datos incompletos o error para Diego & Victor Hugo: 'artist'
# ⚠️ Datos incompletos o error para Remixing Mohit RM: 'artist'
# ⚠️ Datos incompletos o error para Prakash Rawat: 'artist'
# ⚠️ Datos incompletos o error para Emile Ford & The Checkmates: 'artist'
# ⚠️ Datos incompletos o error para Pradeep Sharma,Rahul Prajapati: 'artist'
# ⚠️ Datos incompletos o error para BRACE THORN SHIRIMANI: 'artist'
# ⚠️ Datos incompletos o error para Otis Williams & The Charms: 'artist'
# ⚠️ Datos incompletos o error para Balkan Connection South America: 'artist'
# ⚠️ Datos incompletos o error para Otis Williams & The Charms: 'artist'
# ⚠️ Datos incompletos o error para Uchhaba Charan Das: 'artist'
# ⚠️ Datos incompletos o error para Fernando & Sorocaba: 'artist'
# ⚠️ Datos incompletos o error para Prakash Rawat: 'artist'
# ⚠️ Datos incompletos o error para Thomas Baskey: 'artist'
# ⚠️ Datos incompletos o error para Leandro & Romário: 'artist'
# ⚠️ Datos incompletos o error para Guilherme & Benuto: 'artist'
# ⚠️ Datos incompletos o error para Vitor & Cadu: 'artist'
# ⚠️ Datos incompletos o error para Prabhu Negi: 'artist'
# ⚠️ Datos incompletos o error para Vicky Oraon: 'artist'
# ⚠️ Datos incompletos o error para The Guy Who Sings Songs About Cities & Towns: 'artist'
# ⚠️ Datos incompletos o error para The Guy Who Sings Songs About Cities & Towns: 'artist'
# ⚠️ Datos incompletos o error para Shashank Hulagur: 'artist'
# ⚠️ Datos incompletos o error para Prabhu Negi: 'artist'
# ⚠️ Datos incompletos o error para Prabhu Negi: 'artist'
# ⚠️ Datos incompletos o error para Amulya Dansena: 'artist'
# ⚠️ Datos incompletos o error para Jadumani Patel: 'artist'
# ⚠️ Datos incompletos o error para Dj Rupendra Style: 'artist'
# ⚠️ Datos incompletos o error para Teju Negi: 'artist'
# ⚠️ Datos incompletos o error para Vijay Panchal: 'artist'
# ⚠️ Datos incompletos o error para Ajoy Phukan: 'artist'
# ⚠️ Datos incompletos o error para Marwari Brothers: 'artist'
# ⚠️ Datos incompletos o error para MALLIKA PATIR: 'artist'
# ⚠️ Datos incompletos o error para Shankar Thapa: 'artist'
# ⚠️ Datos incompletos o error para R. K. Singh: 'artist'
# ⚠️ Datos incompletos o error para Barun Babua: 'artist'
# ⚠️ Datos incompletos o error para Lew Jetton & 61 South: 'artist'
# ⚠️ Datos incompletos o error para +plattform: 'artist'
# ⚠️ Datos incompletos o error para SuperTab Radio with Super8 & Tab: 'artist'
# ⚠️ Datos incompletos o error para salman singar mewati: 'artist'
# ⚠️ Datos incompletos o error para Humberto & Ronaldo: 'artist'
# ⚠️ Datos incompletos o error para R. K. Singh: 'artist'
# ⚠️ Datos incompletos o error para Santosh Katria: 'artist'
# ⚠️ Datos incompletos o error para Rajiv Raj: 'artist'
# ⚠️ Datos incompletos o error para Emile Ford & The Checkmates: 'artist'
# ⚠️ Datos incompletos o error para Angchuk: 'artist'
# ⚠️ Datos incompletos o error para Bhusan Mundu: 'artist'
# ⚠️ Datos incompletos o error para Humberto & Ronaldo: 'artist'
# ⚠️ Datos incompletos o error para Sahin Chanchal Mewati: 'artist'
# ⚠️ Datos incompletos o error para Cacio & Marcos: 'artist'
# ⚠️ Datos incompletos o error para Gabbu Bhai: 'artist'
# ⚠️ Datos incompletos o error para The Guy Who Sings Songs About Cities & Towns: 'artist'
# ⚠️ Datos incompletos o error para Sahin Chanchal Mewati: 'artist'
# ⚠️ Datos incompletos o error para Anokha Ji: 'artist'
# ⚠️ Datos incompletos o error para Sumina Singh: 'artist'
# ⚠️ Datos incompletos o error para Sagar Janaradan: 'artist'
# ⚠️ Datos incompletos o error para Theo & Luan: 'artist'
# ⚠️ Datos incompletos o error para Sana Khan Mewati: 'artist'
# ⚠️ Datos incompletos o error para Manoj Bhaskar: 'artist'
# ⚠️ Datos incompletos o error para Gustavo Toledo & Gabriel: 'artist'
# ⚠️ Datos incompletos o error para Debabrata Majumdar: 'artist'
# ⚠️ Datos incompletos o error para Jackie Gajjar: 'artist'
# ⚠️ Datos incompletos o error para Hritik Gua: 'artist'
# ⚠️ Datos incompletos o error para Theo & Luan: 'artist'
# ⚠️ Datos incompletos o error para Sana Khan Mewati: 'artist'
# {'nombre_artista': ['Marisol', 'Da Igual', 'Los Rebeldes', 'Eladio y Los Seres Queridos', 'Los Directivos', 'Duo Dinamico', 'Kañasur', 'Neleonard', 'Son Del Barrio', 'Maria Carrasco', 'Ketito', 'Roberto Casalino', 'Luisa Lacerda', 'Nechivile', 'Xabi Bandini', 'Ataque Escampe', 'Os Amigos dos Músicos', 'Planet Funk', 'Young Forest', 'Igor Paskual', 'Ruiperez', 'Los eternos', 'Sutan', 'Onki Xin', 'Ruxe Ruxe', 'Kitai', 'Alejandro Conde', 'Supercobra', 'Johnny Preston', 'Jardim Soma', 'Los Ghoul Espantos', 'Smile And Burn', 'Los Muecas', 'Juan Hernández y Su Banda de Blues', 'Disco Van', 'Marco Ginelli', 'AAAA', 'Yan Oxygen', 'Hernan Bass', 'Norberto Lusso', 'Sven Kuhlmann', 'Peppelino', 'Manu Sami', 'Ken Karter', "Disco Ball'z", 'Duck Sandoval', 'Dkult', 'Qoso', 'Lorenzo Al Dino', 'Zareh Kan', 'Dj Scale Ripper', 'Javier Marimon', 'Sebastian Konrad', 'Droneghost', 'Q-Lee', 'DJ D ReDD', 'Random Sequence', 'Omega Drive', 'Steve Menta', 'MOD3LLR', 'Phaedon', 'Israel Toledo', 'Gaboo', 'Alexskyspirit', 'Har-El', 'Nicolas Rada', 'Bynomic', 'Milos Miladinovic', 'Chris Hampshire', 'Armos', 'Madloch', "Ferry Corsten's Countdown", 'Eric Senn', 'Roman Messer Suanda Radio', 'Armin van Buuren ASOT Radio', 'Andrew Rayel', "Cosmic Gate's Wake Your Mind Radio", 'Luke Terry', 'California Sunshine', 'Above & Beyond Group Therapy', 'Markus Schulz - Global DJ Broadcast', 'Tom Exo', 'Aly & Fila', 'Nick Newman', 'Indi', 'Airwave', 'S.H.O.K.K.', 'Second Reason', 'Aevus', 'Tom Wax', 'Los Relicarios', 'Alberto Cortez', 'Abhijit Majumdar', 'Bhakta Prasad Barik', 'Dikshu', 'Mithu Marshal', 'Aakangkhya Das', 'Raju Rawal', 'Akshaya Mohanty', 'Mohini Pandey Priti', 'Guto Lima', 'Locosounds', 'Dinesh Lal Yadav', 'สุรสีห์ อิทธิกุล', 'Güzide Kasacı', 'Ramesh Roshan', 'Bubblegum Lemonade', 'Ernest Ashworth', 'Singrai Soren', 'George Jones', 'Alma Cogan', 'Nazia Iqbal', 'Jike Junyi', 'Pawan Singh', 'Jendral Kantjil', 'Captivate', 'Klisee', 'Joe Brown', 'Domenico Modugno', 'Indra Dhavsi', 'Baidyanath Dash', 'Nataliya Vlasova', 'Justin Time for Christmas', 'Hozan Reşo', 'Daia', 'Lama Sidibe', 'Ajungi', 'Porter Wagoner', 'Paola Iezzi', 'Lee ALeum', 'Paha Kaksonen', 'Charlie Monttana', 'William Harries Graham', 'Star Arcana', 'Tommy Steele', 'XO Planets', 'Companero Asma', 'Full Nothing', 'Aarktica', 'BETAMENSCH', 'Don Vail', 'Bobby Rydell', 'UNICORN', 'Garage 21', 'Durango14', 'The Space Wizards', 'FLOWERS', 'Billy Fury', 'Resgate', 'Julio Igrejas', 'Maneki Kecak', 'Lucas Lyra', 'The High Dials', 'Wander', 'The Residents', 'Stay Away', 'An Early Bird', 'Sketchquiet', 'Zander', 'Nei Van Soria', 'Christmas', 'Merzbow', 'Nae:Tek', 'Tender H', 'Abbeloos Olivier', 'Goncalo M', 'Hunter/Game', 'Damon Paul', 'ÁCIDA ÁCIDA', 'Evil Jokes', 'Mown', 'Greg Denbosa', 'Atlaxsys', 'Seventh Sea', 'Balrog', 'Sopik', 'Corner', 'Deeperwalk', 'H.N.P', 'Melodymann', 'David Temessi', 'Fernie', 'Krisz Deak', 'Remute', 'George Libe', 'Hans Bouffmyhre', 'Manel Diaz', 'R.Hz', 'Chipi', 'Roman Faero', 'Kinko', 'Cemento', 'Andreas Gehm', 'Ricardo Piedra', 'North Core Project', 'Chris Giuliano', 'Neogenia', 'Stargazers', 'Goa Doc', 'Ian Source', 'DoctorSpook', 'Pedro Capelossi', 'Eric Lune', 'Matt Darey', 'Major7', 'Ori Uplift', 'Blank & Jones', 'Madwave', 'Nima Rafi', 'pepetterz', 'Netherfriends', "The Arizona's", 'Mario Battaini', 'Betty Curtis', 'Alireza Roozegar', 'Jose Muñoz', 'Vijay Chauhan', 'Roberto Murolo', 'خميس ناجي', 'Yung Muse', 'Renuka Panwar', '純情のアフィリア', 'Shohruhxon', 'Escarião', 'Gunjan Singh', 'Tai the Rapper', 'Maia Hirasawa', 'tuunnvvx', 'Seketh Bárbara', 'DAP The Contract', 'Kaé', 'Tamboerijn', 'Marc Almond', 'Subash Dash', 'Chinar Music', 'Udit Narayan', 'Usha Uthup', 'Enrico Musiani', 'มหัศจรรย์ธรรมดา', 'Nitesh Kachhap', 'Reyna Lucero', 'Румиса Никаева', 'Marty Wilde', 'Rick Wakeman', 'WONDERGEL', 'Выход', 'Mean Jolene', 'The Jodimars', 'Mike Bloomfield', 'Glen Ricks', 'Electric Lo Fi Seresta', 'Marcia Griffiths', 'Bulat Okudzhava', 'Manfred Mann Chapter Three', 'Namo Fusion', ...

# %%
df=pd.DataFrame(infoartistas_lastfm)

# %%
df
# Out:
#                    nombre_artista  \
# 0                         Marisol
# 1                        Da Igual
# 2                    Los Rebeldes
# 3     Eladio y Los Seres Queridos
# 4                  Los Directivos
# ...                           ...
# 1902                     Syntouch
# 1903                       Ascent
# 1904                 Roman Messer
# 1905                 Digital Mess
# 1906                      J Nitti
#
#                                                     bio listeners playcount  \
# 0     Marisol (o Pepa Flores, su nombre real) es una...     46644    293612
# 1     Wences Sánchez empieza a despuntar desde bien ...       723      8850
# 2     Los Rebeldes is a Spanish Rock and Roll / Rock...     23226    160468
# 3      <a href="https://www.last.fm/music/Eladio+y+L...      4241     59382
# 4      <a href="https://www.last.fm/music/Los+Direct...       881     31467
# ...                                                 ...       ...       ...
# 1902   <a href="https://www.last.fm/music/Syntouch">...      1950     12823
# 1903  There are at least four artists known as "Asce...      9631     65415
# 1904  A new star shines in the sky of trance music -...     60309    804508
# 1905   <a href="https://www.last.fm/music/Digital+Me...      4696     21251
# 1906  FILIPPO J.NITTI J Nitti aka Filippo started sp...      2476      7456
#
#                                                 similar
# 0     [Massiel, Los Secretos, Mocedades, Nino Bravo,...
# 1     [Barrio Sur, nada que decir, Doctor Pitangú, E...
# 2     [Gatos Locos, Loquillo y Trogloditas, Loquillo...
# 3     [elodio y los seres queridos, Grises, Lovely L...
# 4     [Anntona, Los lagos de Hinault, Espanto, La es...
# ...                                                 ...
# 1902  [Manuel Rocca, Alternate High, Ross Rayer, Inn...
# 1903  [Argus, Ascent & Argus, E-Mantra, Suduaya, Mal...
# 1904  [Michael Milov, Tycoos, Alexander Popov, Eximi...
# 1905  [Artyom junior, re axis, Alberto Fracasso, Ric...
# 1906  [Chable, Antillas, Chriss Ortega, Bjornberg, T...
#
# [1907 rows x 5 columns]

# %%
# guardamos la información en un archivo .csv sobre los 1907 artistas que aparecen en LastFm:
df.to_csv("lastfmdatabase.csv")

# %%
df_values_lastfm=pd.read_csv("lastfmdatabase.csv",index_col=0)

# %%
values_lastfm = list(df_values_lastfm.itertuples(index=False, name=None))
# aqui no incluye ni el índice ni los títulos de las colmnas

# %% [markdown]
# FUNCIÓN CREAR BASES DE DATOS:

# %%
def crear_base_datos(nombre_bd, user='root', password='AlumnaAdalab', host='127.0.0.1'):

    try:
        cnx = mysql.connector.connect(user=user, password=password, host=host)
        mycursor = cnx.cursor()
        sql = f"CREATE DATABASE {nombre_bd}"
        mycursor.execute(sql)
        print(f"✅ Base de datos `{nombre_bd}` creada correctamente.")
    except mysql.connector.Error as err:
        print(f"❌ Error al crear la base de datos `{nombre_bd}`.")
        print("Error Code:", err.errno)
        print("SQLSTATE:", err.sqlstate)
        print("Message:", err.msg)
    finally:
        mycursor.close()
        cnx.close()

# %%
nombre_bd = "MusicTrends"
crear_base_datos(nombre_bd)
# Out:
# ✅ Base de datos `MusicTrends` creada correctamente.

# %% [markdown]
# FUNCIÓN CREAR TABLAS:

# %%
def crear_tablas(queries, user='root', password='AlumnaAdalab', host='127.0.0.1', database='MusicTrends'):

    try:
        cnx = mysql.connector.connect(user=user, password=password, host=host, database=database)
        mycursor = cnx.cursor()

        for sql in queries:
            mycursor.execute(sql)
            cnx.commit()
            print(f"✅ Tabla creada")

    except mysql.connector.Error as err:
        print(f"❌ Error al crear tablas.")
        print("Error Code:", err.errno)
        print("SQLSTATE:", err.sqlstate)
        print("Message:", err.msg)
    finally:
        mycursor.close()
        cnx.close()

# %%
queries = [
        """
        CREATE TABLE IF NOT EXISTS LastFM (
            id_artista INT AUTO_INCREMENT NOT NULL,
            nombre_artista VARCHAR(100) NOT NULL,
            bio LONGTEXT NULL,
            listeners INT NULL,
            playcount INT NULL,
            similar LONGTEXT NULL,
            PRIMARY KEY (id_artista)
        )
        """,
        """
        CREATE TABLE IF NOT EXISTS Spotify (
            id_track INT NOT NULL AUTO_INCREMENT,
            nombre_canción VARCHAR(200) NULL,
            nombre_artista VARCHAR(100) NOT NULL,
            id_artista INT NULL,
            año_lanzamiento VARCHAR(4),
            género_musical VARCHAR(45) NULL,
            tipo VARCHAR(10) NULL,
            PRIMARY KEY(id_track),
            CONSTRAINT fk_LastFM FOREIGN KEY (id_artista) 
                REFERENCES LastFM(id_artista) 
                ON DELETE CASCADE 
                ON UPDATE CASCADE
        )
        """
    ]
crear_tablas(queries)
# Out:
# ✅ Tabla creada
# ✅ Tabla creada

# %% [markdown]
# FUNCIÓN INSERTAR DATOS:
#
# Al crear las tablas hemos definido:
# - PRIMARY KEY (id_artista) en la tabla LastFM
# - PRIMARY KEY(id_track) en la tabla Spotify y REFERENCES LastFM(id_artista), por lo que Spotify(id_artista) depende de  LastFM(id_artista)
#
#
# Como los datos de id_artista de Spotify dependen de los id_artista de LastFM, tenemos que realizar las cargas (función insertar_datos) comenzando siempre por la carga de valores de LastFM + la query de LastFM. A continuación obtenemos los artistas que tenemos en ésta tabla de LastFM con la función obtener_diccionario_artistas y los convertimos en valores_spotify con la función preparar_valores_spotify. Una vez tenemos estos valores_spotify podremos realizar la carga de datos en Spotify con la función insertar_datos y la carga de valores de Spotify + la query de Spotify

# %%
def insertar_datos(sql, valores, user='root', password='AlumnaAdalab', host='127.0.0.1', database='MusicTrends'):

    try:
        cnx = mysql.connector.connect(user=user, password=password, host=host, database=database)
        mycursor = cnx.cursor()
        mycursor.executemany(sql, valores)
        cnx.commit()
        print(f"✅ {mycursor.rowcount} registro(s) insertado(s).")
    except mysql.connector.Error as err:
        print(f"❌ Error al insertar datos.")
        print("Error Code:", err.errno)
        print("SQLSTATE:", err.sqlstate)
        print("Message:", err.msg)
    finally:
        mycursor.close()
        cnx.close()

# %%
# para llamar a la función es necsario darle la query de LastFM y los values de LastFM:
sql = "INSERT INTO LastFM (nombre_artista, bio, listeners, playcount, similar) VALUES (%s, %s, %s, %s,%s)"
valores = values_lastfm
insertar_datos(sql, valores)
# Out:
# ✅ 1907 registro(s) insertado(s).

# %%
def obtener_diccionario_artistas(user='root', password='AlumnaAdalab', host='127.0.0.1', database='MusicTrends'):
    try:
        cnx = mysql.connector.connect(user=user, password=password, host=host, database=database)
        mycursor = cnx.cursor()
        mycursor.execute("SELECT id_artista, nombre_artista FROM LastFM")
        artistas = mycursor.fetchall()
        diccionario_artistas = {nombre.lower(): id for id, nombre in artistas}
        print(f"✅ Diccionario de {len(diccionario_artistas)} artistas cargado.")
        return diccionario_artistas
    except mysql.connector.Error as err:
        print(f"❌ Error al obtener artistas.")
        print("Error Code:", err.errno)
        print("SQLSTATE:", err.sqlstate)
        print("Message:", err.msg)
        return {}
    finally:
        mycursor.close()
        cnx.close()

# %%
diccionario_artistas = obtener_diccionario_artistas()
# Out:
# ✅ Diccionario de 1907 artistas cargado.

# %%
def preparar_valores_spotify(valores_spotify, diccionario_artistas):
    values_spotify = []
    for fila in valores_spotify:
        nombre_artista = fila[0].lower()
        id_artista = diccionario_artistas.get(nombre_artista)

        if id_artista is not None:
            values_spotify.append((id_artista, *fila))
        else:
            values_spotify.append((None, *fila))
            print(f"⚠️ Artista no encontrado en LastFM: {nombre_artista}")
    return values_spotify

# %%
valores_spotify = preparar_valores_spotify(values_spotify, diccionario_artistas)
# Out:
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: kuber geetpariha
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: pankaj,monika,pawan
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: dj rupendra style
# ⚠️ Artista no encontrado en LastFM: harendar,monika,azad ansari
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: azad ansari,manju devi
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: azad ansari,manju devi
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: kc & the sunshine band
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: pawan, pankaj,monika
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: pankaj,monika,pawan
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: manoj sahri,monika
# ⚠️ Artista no encontrado en LastFM: pankaj,pawan
# ⚠️ Artista no encontrado en LastFM: bharti studio
# ⚠️ Artista no encontrado en LastFM: mr. man & the big eyes
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: rng bros
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: sargam audio
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: d n mishra
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: kc & the sunshine band
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: joão neto & frederico
# ⚠️ Artista no encontrado en LastFM: diego & victor hugo
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: diego & victor hugo
# ⚠️ Artista no encontrado en LastFM: remixing mohit rm
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: prakash rawat
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: emile ford & the checkmates
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: pradeep sharma,rahul prajapati
# ⚠️ Artista no encontrado en LastFM: brace thorn shirimani
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: otis williams & the charms
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: balkan connection south america
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: otis williams & the charms
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: uchhaba charan das
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: fernando & sorocaba
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: prakash rawat
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: thomas baskey
# ⚠️ Artista no encontrado en LastFM: leandro & romário
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: guilherme & benuto
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: vitor & cadu
# ⚠️ Artista no encontrado en LastFM: prabhu negi
# ⚠️ Artista no encontrado en LastFM: vicky oraon
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: the guy who sings songs about cities & towns
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: the guy who sings songs about cities & towns
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: shashank hulagur
# ⚠️ Artista no encontrado en LastFM: prabhu negi
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: prabhu negi
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ...
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: theo & luan
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: sana khan mewati
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: manoj bhaskar
# ⚠️ Artista no encontrado en LastFM: gustavo toledo & gabriel
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: debabrata majumdar
# ⚠️ Artista no encontrado en LastFM: jackie gajjar
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: hritik gua
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: theo & luan
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: sana khan mewati
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists
# ⚠️ Artista no encontrado en LastFM: various artists

# %%
# y una vez realizadas las siguientes 2 funciones podremos cargar los datos de Spotify con la función insertar_datos y:
sql = "INSERT INTO Spotify (id_artista, nombre_artista, nombre_canción, año_lanzamiento, género_musical, tipo) VALUES (%s, %s, %s, %s, %s, %s)"
valores = valores_spotify
insertar_datos(sql, valores)
# Out:
# ✅ 5000 registro(s) insertado(s).
